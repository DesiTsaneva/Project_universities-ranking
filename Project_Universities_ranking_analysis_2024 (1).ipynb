# %%
import pandas as pd

#How many universities are there in the dataset?

#How many different countries are there?

#What is the distribition of contries in top 100 universities?

#What is the average number of students in top 10 universities?

#Which are the top 10 universities with more than 50% international student?

#Which are the top 10 universities with a predominantly female presence?

# %%
df = pd.read_csv(r"C:\Users\Desi\Downloads\World+University+Rankings+2023.csv")
df
# Out:
#      University Rank                     Name of University        Location  \
# 0                  1                   University of Oxford  United Kingdom
# 1                  2                     Harvard University   United States
# 2                  3                University of Cambridge  United Kingdom
# 3                  3                    Stanford University   United States
# 4                  5  Massachusetts Institute of Technology   United States
# ...              ...                                    ...             ...
# 2336               -     University of the West of Scotland             NaN
# 2337               -                  University of Windsor             NaN
# 2338               -            University of Wolverhampton             NaN
# 2339               -                University of Wuppertal             NaN
# 2340               -    Xi’an Jiaotong-Liverpool University             NaN
#
# ...

# %%
pd.set_option("display.max_columns",13)

# %%
pd.set_option("display.max_rows",2341)

# %%
df
# Out:
#      University Rank                                 Name of University  \
# 0                  1                               University of Oxford
# 1                  2                                 Harvard University
# 2                  3                            University of Cambridge
# 3                  3                                Stanford University
# 4                  5              Massachusetts Institute of Technology
# 5                  6                 California Institute of Technology
# 6                  7                               Princeton University
# 7                  8                 University of California, Berkeley
# 8                  9                                    Yale University
# 9                 10                            Imperial College London
# 10                11                                Columbia University
# 11                11                                         ETH Zurich
# ...

# %%
df=df.drop_duplicates()

# %%
Number_universities = df["Name of University"].unique()

# %%
Number_universities
# Out:
# array(['University of Oxford', 'Harvard University',
#        'University of Cambridge', ..., 'University of Wolverhampton',
#        'University of Wuppertal', 'Xi’an Jiaotong-Liverpool University'],
#       dtype=object)

# %%
len(Number_universities)
# Out:
# 2234

# %%
for i in Number_universities:
    print(i)
# Out:
# University of Oxford
# Harvard University
# University of Cambridge
# Stanford University
# Massachusetts Institute of Technology
# California Institute of Technology
# Princeton University
# University of California, Berkeley
# Yale University
# Imperial College London
# Columbia University
# ETH Zurich
# The University of Chicago
# University of Pennsylvania
# Johns Hopkins University
# Tsinghua University
# Peking University
# University of Toronto
# National University of Singapore
# Cornell University
# University of California, Los Angeles
# UCL
# University of Michigan-Ann Arbor
# New York University
# Duke University
# Northwestern University
# University of Washington
# Carnegie Mellon University
# University of Edinburgh
# Technical University of Munich
# University of Hong Kong
# University of California, San Diego
# LMU Munich
# University of Melbourne
# King’s College London
# Nanyang Technological University, Singapore
# London School of Economics and Political Science
# ...

# %%
unique_countries_count = df['Location'].nunique()

# %%
unique_countries_count
# Out:
# 116

# %%
for i in df['Location'].dropna().drop_duplicates():
    print(i)
# Out:
# United Kingdom
# United States
# Switzerland
# Canada
# Australia
# Singapore
# Japan
# France
# Sweden
# China
# South Korea
# Netherlands
# Germany
# Belgium
# Finland
# Denmark
# Austria
# Norway
# New Zealand
# Spain
# Italy
# Saudi Arabia
# Luxembourg
# Qatar
# Brazil
# Israel
# Ireland
# Taiwan
# India
# United Arab Emirates
# Brunei Darussalam
# Iceland
# Lebanon
# Philippines
# Portugal
# Iran
# Malaysia
# Poland
# Egypt
# Turkey
# Greece
# Vietnam
# Algeria
# Nigeria
# Tanzania
# Chile
# Pakistan
# Ukraine
# Romania
# Czech Republic
# South Africa
# Northern Cyprus
# Hong Kong
# Ethiopia
# Jordan
# Serbia
# Sri Lanka
# Jamaica
# Zambia
# Iraq
# Costa Rica
# Cyprus
# Bangladesh
# Mozambique
# Colombia
# Kenya
# Namibia
# Peru
# Latvia
# Oman
# Thailand
# Lithuania
# Slovenia
# Uganda
# Malta
# Nepal
# Kazakhstan
# Mexico
# Botswana
# Slovakia
# Ghana
# Morocco
# Georgia
# Tunisia
# Mauritius
# Hungary
# Puerto Rico
# Ecuador
# Fiji
# Croatia
# Estonia
# Zimbabwe
# Indonesia
# ...

# %%
unique_counries = df['Location'].dropna().drop_duplicates()
unique_counries.reset_index()
# Out:
#      index              Location
# 0        0        United Kingdom
# 1        1         United States
# 2       11           Switzerland
# 3       17                Canada
# 4       33             Australia
# 5       35             Singapore
# 6       38                 Japan
# 7       46                France
# 8       48                Sweden
# 9       50                 China
# 10      55           South Korea
# 11      58           Netherlands
# 12      72               Germany
# 13     106               Belgium
# 14     109               Finland
# 15     113               Denmark
# 16     124               Austria
# 17     125                Norway
# 18     138           New Zealand
# 19     180                 Spain
# 20     182                 Italy
# 21     212          Saudi Arabia
# 22     216            Luxembourg
# 23     224                 Qatar
# 24     230                Brazil
# 25     239                Israel
# 26     241               Ireland
# ...

# %%
top_100_df = df.sort_values(by='OverAll Score', ascending=False).head(100)

# %%
top_100_df
# Out:
#    University Rank                                 Name of University  \
# 0                1                               University of Oxford
# 1                2                                 Harvard University
# 2                3                            University of Cambridge
# 3                3                                Stanford University
# 4                5              Massachusetts Institute of Technology
# 5                6                 California Institute of Technology
# 6                7                               Princeton University
# 7                8                 University of California, Berkeley
# 8                9                                    Yale University
# 9               10                            Imperial College London
# 11              11                                         ETH Zurich
# 10              11                                Columbia University
# ...

# %%
distrubution_top_100_countries = top_100_df["Location"].unique()

# %%
distrubution_top_100_countries
# Out:
# array(['United Kingdom', 'United States', 'Switzerland', nan, 'Canada',
#        'Australia', 'Singapore', 'Japan', 'France', 'Sweden', 'China',
#        'South Korea', 'Netherlands', 'Germany'], dtype=object)

# %%
top_ten_universities = df.sort_values(by='OverAll Score', ascending=False).head(10)

# %%
top_ten_universities

# %%
top_ten_universities["No of student"] = top_ten_universities["No of student"].str.replace(',', '').astype(float)

# %%
top_ten_universities["No of student"].mean()
# Out:
# 17408.0

# %%
top_ten_female = df.sort_values(by='Female:Male Ratio', ascending=False).head(10)

# %%
top_ten_female
# Out:
#      University Rank                                 Name of University  \
# 1842        Reporter                                   Effat University
# 1199       1201–1500    Chang Gung University of Science and Technology
# 670          601–800             Imam Abdulrahman Bin Faisal University
# 2147        Reporter                Tashkent State Transport University
# 592          501–600                                   Zayed University
# 2203        Reporter                   Yamaguchi Prefectural University
# 2043        Reporter                          Nursing School of Coimbra
# 2185        Reporter  University of Veterinary Medicine and Pharmacy...
# 2118        Reporter  Sri Padmavati Mahila Visvavidyalayam (Women's ...
# 1719        Reporter  Alisher Navo’i Tashkent State University of Uz...
#
#                   Location No of student  No of student per staff  \
# 1842          Saudi Arabia         1,067                      9.4
# ...

# %%
top_international = df.sort_values(by='International Student', ascending=False).head(10)

# %%
top_international
# Out:
#      University Rank                                 Name of University  \
# 1798        Reporter                    César Ritz Colleges Switzerland
# 1968        Reporter                             London Business School
# 218          201–250         Macau University of Science and Technology
# 172              174  Ulsan National Institute of Science and Techno...
# 50                51                                   Fudan University
# 459          401–500     Norwegian University of Science and Technology
# 551          501–600      Missouri University of Science and Technology
# 833         801–1000                                 University of Jaén
# 946         801–1000                                 Vilnius University
# 647          601–800                           Eötvös Loránd University
#
#             Location No of student  No of student per staff  \
# 1798     Switzerland           547                      4.8
# ...
